# %% [markdown]
# <a href="https://colab.research.google.com/github/Rashin-Rafeeq/AI_Assignments/blob/main/Projecct_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5

students = []

def add_student():
    try:
        name = input("Enter student name: ")
        roll_no = int(input("Enter roll number: "))
        marks = []
        for i in range(3):
            m = int(input(f"Enter marks for subject {i+1}: "))
            if m < 0 or m > 100:
                raise ValueError("Marks should be between 0 and 100.")
            marks.append(m)
        students.append({"name": name, "roll_no": roll_no, "marks": marks})
    except ValueError as e:
        print(f"Error: {e}")

def calculate_grade(percentage):
    if percentage >= 90: return "A+"
    elif percentage >= 80: return "A"
    elif percentage >= 70: return "B"
    elif percentage >= 60: return "C"
    else: return "F"

def generate_report():
    try:
        with open("report.txt", "w") as report:
            for student in students:
                total = sum(student["marks"])
                percentage = total / len(student["marks"])
                grade = calculate_grade(percentage)
                report.write(f"{student['name']} | Roll: {student['roll_no']} | Total: {total} | %: {percentage:.2f} | Grade: {grade}\n")
        print("Report generated successfully!")
    except Exception as e:
        print(f"Error: {e}")

def save_students():
    try:
        with open("students.txt", "w") as file:
            for student in students:
                file.write(f"{student['name']},{student['roll_no']},{','.join(map(str, student['marks']))}\n")
        print("Student data saved successfully!")
    except Exception as e:
        print(f"Error: {e}")

#Menu
while True:
    print("\n1. Add Student\n2. Generate Report\n3. Save Students\n4. Exit")
    choice = input("Enter choice: ")
    if choice == "1":
        add_student()
    elif choice == "2":
        generate_report()
    elif choice == "3":
        save_students()
    elif choice == "4":
        break
    else:
        print("Invalid choice!")
# Out:
# 1. Add Student
# 2. Generate Report
# 3. Save Students
# 4. Exit
# Enter choice: 1
# Enter student name: vishnu
# Enter roll number: 2
# Enter marks for subject 1: 50
# Enter marks for subject 2: 60
# Enter marks for subject 3: 80
#
# 1. Add Student
# 2. Generate Report
# 3. Save Students
# 4. Exit
# Enter choice: 3
# Student data saved successfully!
#
# 1. Add Student
# 2. Generate Report
# 3. Save Students
# 4. Exit
# Enter choice: 2
# Report generated successfully!
#
# 1. Add Student
# 2. Generate Report
# 3. Save Students
# 4. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3031393369.py in <cell line: 0>()
#      48 while True:
#      49     print("\n1. Add Student\n2. Generate Report\n3. Save Students\n4. Exit")
# ---> 50     choice = input("Enter choice: ")
#      51     if choice == "1":
#      52         add_student()
#
# ...
